# %% [markdown]
# ### Lists

# %%
job_skills = ['sql', 'tableau', "excel"]
job_skills
# Out:
# ['sql', 'tableau', 'excel']

# %%
job_skills.append('python')
job_skills
# Out:
# ['sql', 'tableau', 'excel', 'python']

# %%
job_skills.remove("tableau")

# %%
len(job_skills)
# Out:
# 3

# %%
job_skills[1]
# Out:
# 'excel'

# %%
job_skills.insert(2, "tableau")

# %%
job_skills
# Out:
# ['sql', 'excel', 'tableau', 'python']

# %%
job_skills[0:2]
# Out:
# ['sql', 'excel']

# %%
job_skills[:]
# Out:
# ['sql', 'excel', 'tableau', 'python']

# %%
job_skills[:1]
# Out:
# ['sql']

# %%
job_skills[::1]
# Out:
# ['sql', 'excel', 'tableau', 'python']

# %%
job_skills[::2]
# Out:
# ['sql', 'tableau']

# %%
job_skills[::3]
# Out:
# ['sql', 'python']

# %% [markdown]
# ### Merge Lists

# %%
luke_skills = ['python', 'bigquery', 'r']
print(id(luke_skills))
kelly_skills = ['python', 'sql', 'looker']
all_skills = luke_skills + kelly_skills
luke_skills += kelly_skills
print(id(luke_skills))
# Out:
# 2896683353536
# 2896683353536

# %%
all_skills
# Out:
# ['python', 'bigquery', 'r', 'python', 'sql', 'looker']

# %%
all_skills[::2]
# Out:
# ['python', 'r', 'sql']

# %%
all_skills[-1]
# Out:
# 'looker'

# %% [markdown]
# ### Unpacking a list into variables

# %%
skill1, skill2, skill3, skill4 = job_skills
print(skill1)
print(skill2)
print(skill3)
print(skill4)
# Out:
# sql
# excel
# tableau
# python

# %%
skill_concerned, *skill_dont_care = job_skills
print(skill_concerned)
print(skill_dont_care)
# Out:
# sql
# ['excel', 'tableau', 'python']

# %% [markdown]
# ### Dictionary

# %%
job_type_skills = {
    'database': 'postgresql', 
    'language': 'python', 
    'library': 'pandas'
}
job_type_skills
# Out:
# {'database': 'postgresql', 'language': 'python', 'library': 'pandas'}

# %%
job_type_skills["library"]
# Out:
# 'pandas'

# %%
job_type_skills.keys()
# Out:
# dict_keys(['database', 'language', 'library'])

# %%
job_type_skills.values()
# Out:
# dict_values(['postgresql', 'python', 'pandas'])

# %%
job_type_skills.update({'cloud': 'google cloud'})

# %%
job_type_skills
# Out:
# {'database': 'postgresql',
#  'language': 'python',
#  'library': 'pandas',
#  'cloud': 'google cloud'}

# %%
job_type_skills['version control'] = 'git'
job_type_skills
# Out:
# {'database': 'postgresql',
#  'language': 'python',
#  'library': 'pandas',
#  'cloud': 'google cloud',
#  'version control': 'git'}

# %% [markdown]
# ### Sets

# %%
skills= {'tableau', 'sql', 'python', 'statistics'}
skills
# Out:
# {'python', 'sql', 'statistics', 'tableau'}

# %%
skills.add('looker')
skills
# Out:
# {'looker', 'python', 'sql', 'statistics', 'tableau'}

# %%
# We can convert list to set 
set(skills) 
# We can convert set to list
list(skills)

# %% [markdown]
# ### Tuples

# %%
skills_Tuples= ('tableau', 'sql', 'python', 'statistics')
skills_Tuples
# Out:
# ('tableau', 'sql', 'python', 'statistics')

# %%
skills_Tuples[1]
# Out:
# 'sql'

# %%
skills_Tuples[0:2]
# Out:
# ('tableau', 'sql')

# %%
help(tuple)
# Out:
# Help on class tuple in module builtins:
#
# class tuple(object)
#  |  tuple(iterable=(), /)
#  |
#  |  Built-in immutable sequence.
#  |
#  |  If no argument is given, the constructor returns an empty tuple.
#  |  If iterable is specified the tuple is initialized from iterable's items.
#  |
#  |  If the argument is a tuple, the return value is the same object.
#  |
#  |  Built-in subclasses:
#  |      asyncgen_hooks
#  |      UnraisableHookArgs
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return bool(key in self).
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(self, key, /)
#  |      Return self[key].
#  |
#  |  __getnewargs__(self, /)
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
# ...

# %%
luke_skills_tuple = ('python', 'bigquery', 'r')
kelly_skills_tuple = ('python', 'sql', 'looker')
luke_skills_tuple + kelly_skills_tuple
# Out:
# ('python', 'bigquery', 'r', 'python', 'sql', 'looker')

# %%
luke_skills_tuple = ('python', 'bigquery', 'r')
print(id(luke_skills_tuple))
kelly_skills_tuple = ('python', 'sql', 'looker')
luke_skills_tuple += kelly_skills_tuple 
print(id(luke_skills_tuple))
# Out:
# 2896683359168
# 2896683413664
